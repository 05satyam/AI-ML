# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Sentence_Transfomer Model Architecture
# Transformer Models: The library utilizes transformer models like BERT, RoBERTa, DistilBERT, etc., which are pre-trained on large corpora and can be fine-tuned for specific tasks.
# Pooling Strategies: After processing input text through a transformer, a pooling layer aggregates token embeddings to form a single embedding for the entire sentence or text. Common strategies include mean, max, and CLS token pooling.
# Applications
# Semantic Textual Similarity: By embedding sentences into high-dimensional vectors, the library can be used to compare and compute similarities between texts, useful for tasks such as duplicate detection or information retrieval.
# Clustering and Classification: Sentence embeddings can be used for text classification or clustering, grouping similar texts together based on their semantic content.
#
#
#
# **Using all-MiniLM-L6-v2 sentence-transformers model that maps sentences to a 384 dimensional dense vector space.

# %%
from datasets import load_dataset
from sentence_transformers import SentenceTransformer
from pinecone import Pinecone, ServerlessSpec
import os
import time
import torch
from tqdm.auto import tqdm
from dotenv import load_dotenv

# %%
load_dotenv()
dataset = load_dataset('quora', split='train[240000:290000]')

# %%
dataset[:1]
# Out:
# {'questions': [{'id': [207550, 351729],
#    'text': ['What is the truth of life?', "What's the evil truth of life?"]}],
#  'is_duplicate': [False]}

# %%
questions = []
for record in dataset['questions']:
    questions.extend(record['text'])
question = list(set(questions))
print('\n'.join(questions[:10]))
print('-' * 50)
print(f'Number of questions: {len(questions)}')
# Out:
# What is the truth of life?
# What's the evil truth of life?
# Which is the best smartphone under 20K in India?
# Which is the best smartphone with in 20k in India?
# Steps taken by Canadian government to improve literacy rate?
# Can I send homemade herbal hair oil from India to US via postal or private courier services?
# What is a good way to lose 30 pounds in 2 months?
# What can I do to lose 30 pounds in 2 months?
# Which of the following most accurately describes the translation of the graph y = (x+3)^2 -2 to the graph of y = (x -2)^2 +2?
# How do you graph x + 2y = -2?
# --------------------------------------------------
# Number of questions: 100000

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
if device != 'cuda':
    print('No cuda.')
model = SentenceTransformer('all-MiniLM-L6-v2', device=device)
# Out:
# No cuda.

# %%
q="Which city has most engineers in USA?"
q_embed=model.encode(q)
q_embed.shape
# Out:
# (384,)

# %%
PINECONE_API_KEY = os.environ['PINECONE_API_KEY']

# %% [markdown]
# For Below code:
#
#     create_index is a method that initializes a new vector index.
#
#     Parameters of create_index
#         name=INDEX_NAME: This specifies the name of the index. This name is used to reference the index in subsequent operations, such as adding or querying vectors.
#
#         dimension=model.get_sentence_embedding_dimension(): This sets the dimensionality of the vectors that will be stored in the index.
#
#         metric='cosine': This defines the metric used to measure similarity between vectors in the index. The cosine similarity metric measures the cosine of the angle between two vectors, providing a value that indicates how similar they are in orientation in the vector space, regardless of their magnitude.
#
#
#         spec=ServerlessSpec(cloud='aws', region='us-west-2'): This parameter specifies the serverless configuration for the index:
#
#         ServerlessSpec: Configuration structure in the Pinecone library that defines how the index should be deployed.
#             cloud='aws': hosted on Amazon Web Services (AWS).
#             region='us-west-2': AWS region where the index will be physically created.

# %%
pc=Pinecone(api_key=PINECONE_API_KEY)
INDEX_NAME="semanticsearchpinecone1"
if INDEX_NAME in [index.name for index in pc.list_indexes()]:
    pc.delete_index(INDEX_NAME)
    
print(INDEX_NAME)
# Out:
# semanticsearchpinecone1

# %%
pc.create_index(name=INDEX_NAME, 
                dimension=model.get_sentence_embedding_dimension(), 
                metric='cosine', 
                spec=ServerlessSpec(cloud='aws', region='us-west-2'))

# %%
index = pc.Index(INDEX_NAME)
print(index)
# Out:
# <pinecone.data.index.Index object at 0x1366d3b50>

# %% [markdown]
# create embeddings and upsert.....

# %%
batch=250
q_vec_limit=10000
questions = question[:q_vec_limit]

import json

for i in tqdm(range(0, len(questions), batch)):
    i_end = min(i+batch, len(questions))
    ids = [str(x) for x in range(i, i_end)]
    metadatas = [{'text': text} for text in questions[i:i_end]]
    print(len(ids), ' - '*10,  metadatas)
    print("-"*50)
# Out:
#   2%|▎         | 1/40 [00:01<00:39,  1.00s/it]
# 250  -  -  -  -  -  -  -  -  -  -  [{'text': "What is the Secret Service's nickname for Trump?"}, {'text': 'Should we really worry about climate change?'}, {'text': "What does the word 'somberi' mean in Tamil?"}, {'text': 'Does 18 month are enough to crack IIT JEE?'}, {'text': 'Do teenage guys fall in love?'}, {'text': 'What did the German soldiers of WWII think of British, US, Canadian, and Soviet soldiers?'}, {'text': 'What is the chemical formula for zinc? How is this determined?'}, {'text': "I'm a 5 letter word. I am normally below you. If you remove my 1st letter, you'll find me above you. If you remove my 1st & 2nd letters, you can't see me. What am I?"}, {'text': 'Survivor TV show: when going to tribal council, how far do the players walk? They often leave during daylight and get there in the dark?'}, {'text': 'Is Google Glass a flop?'}, {'text': "Who are the likely members of Donald Trump's cabinet?"}, {'text': 'What is an OTG pen drive?'}, {'text': "Should I get a fully paid electrical engineering master's degree from KAUST as an international student?"}, {'text': "What is Hillary Clinton's policy regarding India?"}, {'text': 'How many airline cabin crews in the world?'}, {'text': 'How can I write a letter to Kamal Hassan appreciating his latest movies Uthama Villian and Papanasam? What is his mailing address?'}, {'text': 'When is the boston marathon 2016?'}, {'text': 'From where does this aJ+ music background come from?'}, {'text': "In how many different ways can the letters of the word 'MATHEMATICS' be arranged such that the vowels must always come together?"}, {'text': 'What are the venomous spiders of Minnesota?'}, {'text': 'What is the best way to obtain full custody of a child?'}, {'text': 'Which is the best app for learning English vocabulary?'}, {'text': 'Why does my boyfriend feel annoyed by me? Does he even love me?'}, {'text': 'How does buddybuild.com make money?'}, {'text': 'How do I prove the independence of a product of random variables?'}, {'text': 'How much does the average American spend eating out per month?'}, {'text': '20 workers can finish a work in 30 days. After how many days should 5 workers leave the job so the work is completed in 35 days?'}, {'text': 'Will material possession, social status and fortune make me happy?'}, {'text': 'If double stranded DNA has 14% G (guanine), what percent A (adenine), T (thymine) and C (cytosine) would you expect?'}, {'text': 'Which is the most corrupt state in India?'}, {'text': 'Which one is easier to become a billionaire in the future, private equity or hedge funds?'}, {'text': 'What exactly happens in our eyes when we enter a brightly lit room from a dark room?'}, {'text': "Is energy in vacuum real? How do we know that this energy that can be borrowed and returned immediately is real if virtual particles didn't exist then?"}, {'text': 'What did you find out about your teacher that shocked you?'}, {'text': 'What are the best long range rifles used today by any country?'}, {'text': 'Where can I get free online courses with certificate?'}, {'text': 'How do I revise class 12 syllabus in 1 month?'}, {'text': 'What happens if you make a beating heart in a dead human?'}, {'text': 'What should I read now that Gawker has been destroyed?'}, {'text': 'Why do people fall in love?'}, {'text': 'What is the best country for migration?'}, {'text': 'How do I do PG in medicine in USA after MBBS in India?'}, {'text': "I can't do it anymore… the fantasy never lives up to reality. Why?"}, {'text': 'Will international college students be negatively affected if Trump becomes president?'}, {'text': 'Why is Gautamiputra Satakarni not that familiar in the Andhra region?'}, {'text': 'What Java can do?'}, {'text': 'If I have to improve my English so what I have to do?'}, {'text': 'Do animals see ghosts, spirits or other phenomena unseen by humans?'}, {'text': 'Why do people watch sad movies in their leisure?'}, {'text': 'Will Donald Trump’s win in the elections have an impact on India ...
# --------------------------------------------------
#   5%|▌         | 2/40 [00:01<00:36,  1.03it/s]
# 250  -  -  -  -  -  -  -  -  -  -  [{'text': 'How would world history change if the Earth had an obliquity/tilt of 0 degrees?'}, {'text': 'Were playstation 1 games written mainly in C or MIPS assembly?'}, {'text': 'Dating and Relationships: If a girl likes me, but she blocked me on Facebook, MSN, and refused to reply to my texts, what does it mean?'}, {'text': 'Is there a way of disproving the conviction that reality is merely a construct of our mind and essentially a figment of our imagination?'}, {'text': "Why do people mark questions as ambiguous or needing editing on Quora when they're fine?"}, {'text': 'What are the best reference books for learning Java?'}, {'text': 'What is the fees of luxury and brand management course from SP Jain school of global management?'}, {'text': 'Who will be the next Chief Minister of Maharashtra?'}, {'text': 'Why the "GST\' bill is not getting passed?'}, {'text': "How do you delete an instagram account when you don't remember the password or username?"}, {'text': 'Is the SQLite good for my Android application development?'}, {'text': 'Can we add a team member ICPC before online round? We want to move 1 to substitute and add a new member the option is there but just need to confirm?'}, {'text': 'What are the differences between object oriented approach and object based approach?'}, {'text': 'Is 0 a whole number? Why or why not?'}, {'text': 'What’s your favorite reality show?'}, {'text': 'What is the best time to do sex?'}, {'text': 'How do I get trained in digital marketing?'}, {'text': 'Matlab dll error missing?'}, {'text': 'What are some best defensive shots played by Rahul Dravid?'}, {'text': 'What is the biggest/most important decision you took in life that changed its entire trajectory?'}, {'text': "What are some of the funniest advertising fails you've seen?"}, {'text': 'What was the population of Michigan by year from 1850-present?'}, {'text': 'What are your means of subsistence? What I have to fill in the Application for a national visa for Germany?'}, {'text': 'What topics of mathematics do i need to study to start with Competitive Programming?'}, {'text': 'What is El Niño?'}, {'text': 'What is the difference between interference and diffraction?'}, {'text': 'How can I think of a business idea?'}, {'text': 'Is it safe to use aluminum pans or aluminum foil?'}, {'text': 'In what script is English written?'}, {'text': 'What happens to matter when it enters a black hole?'}, {'text': 'What is the worst thing that ever happened to you for being nice?'}, {'text': 'Where can I get a huge choice of high quality wall and floor tiles in Sydney?'}, {'text': 'What is the cost of magic system in Harry Potter?'}, {'text': 'Mba in 40s?'}, {'text': 'Is thanking your bus/cab/taxi driver good etiquette?'}, {'text': 'How do I recover files from a USB flash drive?'}, {'text': 'What will happen in a relationship where both partners are narcissist or where they both have narcissistic tendencies?'}, {'text': 'What is the best online course for studying basic computer science?'}, {'text': 'Should I consume protein shake?'}, {'text': "How would you explain Michael Jackson's skin transform to a 5 years old child?"}, {'text': 'Why is India called the largest democracy in the world, although there are so many larger countries in the world like Russia, China, and America?'}, {'text': 'How can I score above 80 marks in computer in my icse class 10th board exams out of 100?'}, {'text': 'How did Hitler die really?'}, {'text': 'What are the Pros of calculating GDP at market price rather than factor cost?'}, {'text': 'What argument can be made that Jews should marry each other rather than intermarry ?'}, {'text': 'Why do carpenter bee stings hurt so much?'}, {'text': 'How do I improve my physique?'}, {'text': 'How much black money will the government get back after demonetization?'}, {'text': 'How many days in 10000000 seconds?'}, {'text': 'What are the best places to have momos in Kathmandu?'}, {'text': "Why do Googl ...
# --------------------------------------------------
#   8%|▊         | 3/40 [00:02<00:31,  1.16it/s]
# 250  -  -  -  -  -  -  -  -  -  -  [{'text': 'Why is Frederiksberg not a part of Copenhagen?'}, {'text': 'Why are Japan and the U.S. so excited in the world to hold the fake UN backed Tribunal verdict tightly to incite Philippine against China ?'}, {'text': 'Why is Detroit in such ruin, and is it really that bad to live there, or is it just media hype?'}, {'text': 'What is the worst problem of the United States today?'}, {'text': "I can't view my friend's profile on Facebook but I can still message her, what does it mean?"}, {'text': 'Why does Google Chrome keep crashing in Windows 7?'}, {'text': 'Why is time slower near heavy objects?'}, {'text': 'What is Best book for biology class 9?'}, {'text': 'Do INTPs make good poets?'}, {'text': 'Before getting blocked I sent a message in WhatsApp and it showed two ticks at that time. Can I see if the person has seen the message or not?'}, {'text': 'What are distinct symptoms of borderline personality disorder?'}, {'text': 'Which is the best gaming laptop under 60k INR?'}, {'text': 'How many calories should an IT professional consume per day?'}, {'text': "Where can I find a copy of Ask.com's Jeeves' evil twin image?"}, {'text': "Why doesn't the Bible talk about dinosaurs and their extinction?"}, {'text': 'Is there a cheap device available for the common people to measure the Air Quality Index in Indian cities?'}, {'text': 'What are some good side dishes to serve with homemade Mac and cheese?'}, {'text': 'If there were a hole drilled directly from the surface of the planet through the center; what would happen if someone jumped into it?'}, {'text': 'What is the difference between a condo and a townhouse?'}, {'text': 'How similar are Donald Trump and Arvind Kejriwal?'}, {'text': 'What is UDAY for DISComs?'}, {'text': 'Why do dry cell batteries go dead?'}, {'text': "Why is the media not talking about Hillary Clinton's health? She clearly has some serious health issues, but apparently that issue is being avoided."}, {'text': 'Is there any news of a Nintendo 3DS emulator for PC?'}, {'text': 'What are the strongest majors in terms of job prospects and what are the weakest majors at Eckerd College?'}, {'text': 'What are the best rock bands?'}, {'text': 'What are some of the top intelligent IAS interview questions?'}, {'text': 'What are the strongest majors in terms of job prospects and what are the weakest majors at Eastern University?'}, {'text': 'Where can you buy song lyrics?'}, {'text': 'Are there 7 stars hotels in India?'}, {'text': 'Do employees at H&E Equipment Services have a good work-life balance? Does this differ across positions and departments?'}, {'text': 'What is a plane surface?'}, {'text': 'If my Chinese name cannot be read in English, how do I introduce myself?'}, {'text': 'Can H4 visa holders invest in stock markets?'}, {'text': 'What are some Hollywood movies that you love to watch again and again?'}, {'text': "What do you do if FedEx says a package was delivered but you didn't receive it?"}, {'text': 'What do pilots carry in their flight bags?'}, {'text': 'What are the cons regarding new ₹ 500/2000 currency notes?'}, {'text': 'What exactly causes gravity?'}, {'text': 'Why Farsi (Persian) language is not available on Facebook mobile application while its available on the website?'}, {'text': 'Is the electric field in the cavity of a hollow charged conductor zero?'}, {'text': 'Why do cats hate cucumbers?'}, {'text': 'Who is the all time best footballer in India?'}, {'text': 'How do I get over my depression without any external help?'}, {'text': 'What is stock in a company?'}, {'text': 'What does the #aboutlastnight hashtag mean?'}, {'text': 'How do I find out if she likes you by watching her Behavior?'}, {'text': 'What is a way to prepare for a conference?'}, {'text': 'Hw to be a good human resources?'}, {'text': 'What are some affordable and safe beach resorts in Goa?'}, {'text': 'Which are the main differences between socialism and communism?'}, {'text': 'What is the mean ...
# --------------------------------------------------
#  10%|█         | 4/40 [00:03<00:30,  1.17it/s]
# 250  -  -  -  -  -  -  -  -  -  -  [{'text': 'What steps one must take to become an actor in bollywood?'}, {'text': 'What is the greatest NBA basketball team of all time?'}, {'text': "What's your favorite Chinese food?"}, {'text': 'How do I develop a strong attitude and personality?'}, {'text': 'Can I clear IAS if I scored low in B.E & GMAT?'}, {'text': 'As a programmer, what tasks have you automated to make your everyday life easier?'}, {'text': 'Which kind of insurances does a co-working space need?'}, {'text': "Who's the most powerful in the Lord of the Rings?"}, {'text': 'What are the best home exercises to lose weight?'}, {'text': 'What is a moojuvani (మూజువాణి) vote in Assembly?'}, {'text': 'How much do you love your sleep?'}, {'text': 'What is the dating culture like at UC Berkeley?'}, {'text': "Do employees at Lowe's have a good work-life balance? Does this differ across positions and departments?"}, {'text': 'What is SORTEX rice?'}, {'text': 'How do I get wavy hair overnight?'}, {'text': 'What is the most difficult great lesson to teach?'}, {'text': 'What type of order should I place for a stock that is expected in to increase sharply?'}, {'text': 'If I was interviewing for a SWE position in Python, and you were the interviewer, what are the top 5 things about the language that would disappoint you if I did not know them?'}, {'text': "I broke up with my boyfriend, and now I miss him terribly, but I know it was the right decison to end the relationship and I don't want to get back together. How do I best cope with the pain and sadness from missing him in my life?"}, {'text': 'Why does shaking a soda makes it explode?'}, {'text': 'How are pathogens spread?'}, {'text': 'Could a virus infect a virus/other harmful forms like cancer cells and if so what happens?'}, {'text': 'Can I withdraw money with an ATM card in a bank but not in the home branch in India?'}, {'text': 'How is a UFC fighter different from a boxer?'}, {'text': 'What purpose do flies serve?'}, {'text': 'What is the best way to prepare for JEE advance?'}, {'text': 'What is the total duration of foundational training of Assistant Audit Officers (DR) in CAG and where it is held?'}, {'text': 'Why are birthday consider so special?'}, {'text': 'I broke up and now he is threatening saying he will never let me go to another guy. And if we go to police, he will leak our kissin pics/videos. Help?'}, {'text': 'What are some short stories for marriages?'}, {'text': "How do you get rid of fruit flies when they're everywhere?"}, {'text': 'How can the Lewis Structure for NH2NH2 be determined?'}, {'text': 'What is a flywheel (on a car)?'}, {'text': 'How I can become a millionaire?'}, {'text': 'Why was Quora named Quora?'}, {'text': 'How many times has demonetization happened in India?'}, {'text': 'Is Putin related to holy prophet Muhammad?'}, {'text': 'Does the universe have an edge? Does the universe have a limit to its expansion? If so, what happens when the universe reaches its limit?'}, {'text': 'How do Mg and HCl react together? How is the formula determined?'}, {'text': "Is the Conservative right the only major political group in the world that doesn't believe that Climate Change is a serious threat?"}, {'text': 'What would happen if someone dropped from the stratosphere with a wing suit? Could they fly to a country or would they land in the sea, or die?'}, {'text': 'What is your biggest dream and what are you doing to make it your reality?'}, {'text': 'Can I charge my phone with a charger that outputs different amperes than my normal charger?'}, {'text': 'What is the best way to explain the concept of a Fraternity to someone who is not familiar with the American college system?'}, {'text': 'How do I stop caring so much about what other people think of me?'}, {'text': 'What button cell battery is equivalent to the LR1130?'}, {'text': 'Why do the stars in the sky flicker?'}, {'text': "What's the best picture taken of you and why do you think it's the best?"}, {'text':  ...
# --------------------------------------------------
#  12%|█▎        | 5/40 [00:04<00:28,  1.21it/s]
# 250  -  -  -  -  -  -  -  -  -  -  [{'text': 'Where can I get help with voice acting?'}, {'text': 'How to succeed in exams?'}, {'text': 'Can a person with a higher IQ have a lower problem solving ability than someone with a lower IQ?'}, {'text': 'What are my birds thinking?'}, {'text': 'How do I recover a forgotten Gmail password?'}, {'text': "Why don't people who lived in the 1950's have a 1950's accent?"}, {'text': 'Who is Sam Smith?'}, {'text': 'Are UFOs a conspiracy theory?'}, {'text': 'What is the difference between your head voice and your falsetto?'}, {'text': 'What are the advantages of database?'}, {'text': "What is professor Thomas Cormen's favorite data-structure?"}, {'text': 'Can Quora help you get laid?'}, {'text': 'What are some of the best SAT prep books to use?'}, {'text': 'I am planning to drive from Vancouver to Toronto end of October 2016 in a small sized car. Should I put on winter tires? Kindly advise.'}, {'text': 'What do you think about DotA/DotA2?'}, {'text': 'What is your review of I Do (2012 movie)?'}, {'text': 'What do you think of my YouTube channel?'}, {'text': 'I just made 100 million from horse betting, should I tell my friends and family? Huh?'}, {'text': 'Can I change the details in a submitted passport form?'}, {'text': 'What is the best way to rob a bank and get away with it?'}, {'text': 'Why we should marry young?'}, {'text': 'How can I teach a 5-year-old about saving money and investing?'}, {'text': 'How did Oracle make so much money?'}, {'text': "When someone you've known all your life starts backstabbing you, is it really your fault they are doing it?"}, {'text': 'Does the CERN supercollider open portals to other dimensions where other entities could have access to Earth?'}, {'text': 'Which is the best alloy wheel for car?'}, {'text': 'What is the difference between a lateral surface area and a curved surface area?'}, {'text': 'What does Richard Muller think of Ed Witten?'}, {'text': 'What makes you an Indian?'}, {'text': 'How do I lose weight in next 2 months?'}, {'text': 'What is it like to work at Fujitsu?'}, {'text': 'What happens to personal debt after death?'}, {'text': 'Would Hillary Clinton start World War III / War with Russia?'}, {'text': 'How do I self study for the SAT math level 1 and 2?'}, {'text': 'How long should Quora answers be?'}, {'text': 'What are the desires of a kid?'}, {'text': 'Whether a Indian firm can receive US dollar loan?'}, {'text': 'Why do some people hate video games so much?'}, {'text': 'What are the benefits of doing a government job?'}, {'text': 'If you could travel anywhere in the world where would it be and why?'}, {'text': 'More engineering colleges in Tamil Nadu. is it fair one?'}, {'text': 'Did the Federalist Papers make a significant difference in people deciding to adopt the Constitution?'}, {'text': 'Why do Trump supporters believe that Donald Trump can get his platform through congress?'}, {'text': 'What universities does Spectrum Brands recruit new grads from? What majors are they looking for?'}, {'text': 'Is there a cure for cancer?'}, {'text': 'What is intercollegiate business convention (the event planned by Harvard Undergraduate Women in Business) like? Is it worth attending?'}, {'text': 'Is Miami, FL dangerous? Why or why not?'}, {'text': 'Is there an entrance exam for Rhode Island School of Design?'}, {'text': 'Can we convert the IPv4 configuration to IPv6?'}, {'text': 'What are the best cooking schools in India?'}, {'text': 'What is the reason for slow development in cities of India?'}, {'text': 'Is world war 3 likely?'}, {'text': "Why are Samsung's Galaxy Note 7 phones exploding?"}, {'text': 'What animal products are in nail polish? How is nail polish made?'}, {'text': 'What is the placement like for M.Tech students in Computer Science at the IITs?'}, {'text': 'What are some good smoothie recipes?'}, {'text': 'Can I do BA from IGNOU & then apply for CAT if i complete my MBA from an IIM college will the job interviewer discriminate me f ...
# --------------------------------------------------
#  15%|█▌        | 6/40 [00:05<00:29,  1.15it/s]
# 250  -  -  -  -  -  -  -  -  -  -  [{'text': 'What are the best 5 inch to 5.2 inch android smartphones in India till september 2016 under 15k?'}, {'text': 'What are the symptoms of borderline personality disorder?'}, {'text': "What does a senior analyst/associate's average work day comprise of at Morgan Stanley, Barclay's, Credit Suisse and the like in the US?"}, {'text': 'Did you ever write a poem as a casual writer and felt like showing it to the world, just for fun?'}, {'text': 'I cant request Uber, gives "error processing request"?'}, {'text': 'Is being transgender considered a mental illness? How do we know?'}, {'text': 'How long does it take Yelp to add a business listing to its search results once it is created?'}, {'text': 'What is the procedure for admission of international students to ITMO?'}, {'text': 'What is the capital of Mexico?'}, {'text': 'Have the Japanese forgiven the USA for the atomic bombings of Hiroshima and Nagasaki?'}, {'text': 'How can I download mp3 songs directly from websites on my iphone?'}, {'text': 'Is there any difference between net banking and internet banking?'}, {'text': 'What does a bee sting feel like?'}, {'text': 'How do you simplify this radical expression?'}, {'text': 'Who is the real villain in mahabharata?'}, {'text': 'How do you measure usability?'}, {'text': 'Why will there be only one Rahul Dravid?'}, {'text': 'Which television campany received the most Emmy Awards?'}, {'text': 'What are some unexpected things first-time visitors to Pakistan notice?'}, {'text': 'According to the U.S. Constitution, who has the right to vote?'}, {'text': 'I have finished my 12th examination. Everyone says do something different. Is there any such fields which are rarely known but have a great scope in the future?'}, {'text': 'What are the highest paying jobs for 16 year olds?'}, {'text': 'What will be the features in Samsung Galaxy Note 7?'}, {'text': 'Is it safe for a human to eat dog or cat food?'}, {'text': 'How do I add an image to my question?'}, {'text': 'How much calories do burn after having sex?'}, {'text': 'What it means? If a girl is closing door of her home on my face'}, {'text': 'What is the most soul satisfying thing you have ever done in your life?'}, {'text': 'Why is gender discrimination such an sensitive issue?'}, {'text': 'What is the fastest way to learn a language?'}, {'text': 'Which Hollywood actor is totally underrated?'}, {'text': 'Is space really infinite?'}, {'text': 'How can I find out if my husband is cheating?'}, {'text': "Is Dark King Silvers Rayleigh Luffy's uncle?"}, {'text': 'Which among these is best field in B.Tech for further studies in Robotics: mechanical, computer science or electrical?'}, {'text': 'what are some good computer science final year graduation project ideas related to cyber security and machine learning?'}, {'text': 'Is this right to postpone VTU exams on ministers death?'}, {'text': 'What are good side dishes for filet mignon?'}, {'text': 'What should my itinerary look like for 7 day Singapore trip?'}, {'text': 'How can black money brought out by discontinuing 500 and 1000 notes?'}, {'text': 'Do I have to be in the military to join any US special forces?'}, {'text': 'How does vitamin B2 promote healthy eyes and clear vision?'}, {'text': 'What are some interesting movies in 2016?'}, {'text': 'How do I avoid a crush on my friend?'}, {'text': 'How is life in Miami?'}, {'text': 'How can I become genius engineer?'}, {'text': 'What can I do to improve my social life?'}, {'text': 'What color eyes do I have?'}, {'text': 'The Big Bang Theory: Which is the funniest Sheldon Cooper scene?'}, {'text': 'How much does it cost monthly to live in Islamabad, Pakistan?'}, {'text': 'What is the exact definition of a factorial?'}, {'text': 'How do billionaires trust their bodyguards?'}, {'text': 'Who was the first Prime Minister of India?'}, {'text': 'Is Christmas offensive to Muslims?'}, {'text': 'Can a rat kill a lizard?'}, {'text': 'What are the best things to do  ...
# --------------------------------------------------
#  18%|█▊        | 7/40 [00:06<00:28,  1.15it/s]
# 250  -  -  -  -  -  -  -  -  -  -  [{'text': 'Which ETL tools do you prefer and why?'}, {'text': 'What are the advantages and disadvantages of medical technology?'}, {'text': 'What is Puerto Rico?'}, {'text': 'Which certification has more demand in networking field CCIE Data centre or CCIE Security?'}, {'text': 'You slam on the brakes of your car in a panic, and skid a certain distance on a straight level road. If you had been traveling twice as fast, what distance would the car have skidded, under the same conditions?'}, {'text': 'Is it possible that I have depression?'}, {'text': 'What is the primary industry? What are some examples?'}, {'text': 'Where can a person with a mathematics degree work?'}, {'text': 'What do the Chinese think of Russia?'}, {'text': 'How can you make a variable number of variables in python?'}, {'text': 'How can I use Tinder on my Windows desktop?'}, {'text': 'If Michael Bloomberg ran for president in 2016, would he have won?'}, {'text': 'Could Hillary Clinton ask for a recount in the 2016 US Presidential Election?'}, {'text': 'Are men in their 20s interested in dating a single mom with two kids? Or do they prefer single women with no kids?'}, {'text': 'What makes taboo role play erotic?'}, {'text': 'I had my period for 6 days, then 17 days later I got it for 3 more days. Why is this?'}, {'text': 'What was the best memory during your childhood?'}, {'text': 'What are some ways to take screenshots my desktop?'}, {'text': "As humans, as a race, become smarter, will our IQs increase, or will they stay the same, based off the possibility that we'll stop learning information that will eventually be redundant?"}, {'text': 'Can I use regular Dawn dishsoap in my dishwasher instead of dishwasher detergent? If so, how much?'}, {'text': 'How do I to start a new business?'}, {'text': 'How do I make an extra $ 500 a week?'}, {'text': 'What states allow you to buy codeine cough syrup OTC?'}, {'text': "Is India's life better than Canada's?"}, {'text': 'What are the most amazing images you have captured on your iPhone?'}, {'text': 'Can you sum up your life in one sentence?'}, {'text': 'Why are Koreans so tall?'}, {'text': 'How do you end a filibuster?'}, {'text': 'Are Indians the only people who use a spoon and fork together?'}, {'text': 'How many religions are there in the world?'}, {'text': 'Is it intelligent to own firearms?'}, {'text': 'What skills do IT recruiters find rare or hard to fill in India?'}, {'text': 'What are the benefits of applying aloe vera on your face?'}, {'text': 'How do we actually earn from stock trading?'}, {'text': 'What programming languages is used by schools in Ontario and Quebec (Canada)?'}, {'text': "If you're a foreigner living in Japan and money is inconsequential, is it possible to visit South Korea on holidays? If yes, how often?"}, {'text': 'What are the best countries to work and raising childrens?'}, {'text': "What's the diffference between a high earning guy and and average one (same degree, same organization)?"}, {'text': 'How does breathing meditation improve awareness?'}, {'text': 'How will the decision to illegalize the 500 and 1000 Rs notes help to get rid of black money in the Swiss bank or maybe in other foreign banks and currencies?'}, {'text': 'Do we need advertisements? Describe your favourite advertisement / commercial. Why is it appealing?'}, {'text': 'What are some unforgettable evergreen dialogues in Hollywood?'}, {'text': 'How inaccurate is Credit Karma?'}, {'text': 'How can I get peace of mind?'}, {'text': 'What are the scary photos ever?'}, {'text': "What is mark zuckerberg's favorite linux distribution?"}, {'text': 'Is coca tea addictive?'}, {'text': 'Which are the best banks for business in Bangalore?'}, {'text': 'What IS the USE of COPPER water?'}, {'text': 'What tast are you?'}, {'text': 'What is your favorite video game and why?'}, {'text': 'What is the Sahara, and how do the average temperatures there compare to the ones in the Namib Desert?'}, {'text': ' ...
# --------------------------------------------------
#  20%|██        | 8/40 [00:07<00:28,  1.12it/s]
# 250  -  -  -  -  -  -  -  -  -  -  [{'text': 'How it is like being a girl child in India?'}, {'text': 'Do you believe life exists on other planets? During your career, have you come across anything that helped you make up your opinion about this?'}, {'text': 'I just want to die. How can I make it look like an accident?'}, {'text': 'Will low displacement bikes like Yamaha MT-15 or Suzuki GSX-S150 ever be launched in India?'}, {'text': 'What is a good inpatient drug and alcohol rehab center in Clark County KY?'}, {'text': 'How many answers are posted on Quora in a minute and in an hour?'}, {'text': 'What number and interval of tourist visits would maximize the time that a US citizen could legally spend in Canada over a fixed 48 month period?'}, {'text': "My new mobile number is linked to the Facebook account of an unknown person. I'm getting unintended messages from Facebook. How do I solve this issue?"}, {'text': 'Why is my LinkedIn profile picture blurry?'}, {'text': 'Which is worse for the engine, putting diesel in a "petrol car" or petrol in a "diesel car"?'}, {'text': 'What are some best moments of Rio Olympics 2016?'}, {'text': 'What blood type can be found if a mother has type AB blood and the father has type A blood?'}, {'text': 'I am an Indian student going to the US in Fall 2016. How bad will it be for international students if Trump gets elected as President?'}, {'text': "I’ve created a fragrance, but I'm struggling with a catchy name. Any ideas? Maybe that will help trigger something for me."}, {'text': 'How do you write a complaint?'}, {'text': 'Are Chinese men macho?'}, {'text': 'How did Jeff Bezos get to invest in Uber?'}, {'text': "A guy is in love with me. We've been best friends since we were 14. Why is he in love with me?"}, {'text': 'Can thorium fuel be used in batteries?'}, {'text': 'Do you say Merry Christmas?'}, {'text': 'Does anybody do an initiation at Kriya yoga?'}, {'text': "How would you explain to a child why it's okay to kill a pig but not a human or a stray dog?"}, {'text': 'What would happen if you were swallowed by a whale?'}, {'text': 'How did Krunal Patel (BITS Pilani, Goa campus) manage to get a 1.4cr package?'}, {'text': 'Hello friends, is it beneficial for India that our Constitution has been a mixture of many things taken from the Constitutions of different countries?'}, {'text': 'How should I react when a girl I like tells me about another guy she likes?'}, {'text': 'How do EMG pick-ups work?'}, {'text': 'What should be done to improve problem solving?'}, {'text': 'How is the Iranian artist Googoosh pronounced?'}, {'text': 'How do speed sensors work?'}, {'text': 'Could I get asylum?'}, {'text': 'What are the best laptop under $600?'}, {'text': "What's the best book about Rembrandt?"}, {'text': 'How can we make money out of blogs?'}, {'text': 'When will the human race end?'}, {'text': 'How do I improve my cat score?'}, {'text': 'Where can I found high quality custom made hinged or sliding door wardrobes in Sydney?'}, {'text': 'What is the distribution policy of apple?'}, {'text': 'How do girls feel when guy says "suck my dick"?'}, {'text': 'In what aspects is Hillary Clinton better than Trump?'}, {'text': 'What are the important topics in environmental engineering for the GATE in civil?'}, {'text': 'What is Sehwag like in real life?'}, {'text': 'What is a personal loan?'}, {'text': 'How many times a day do a clock’s hands overlap?'}, {'text': 'Is Rolex a non-profit company? And if so, why?'}, {'text': 'Are the analogies that are being made between SpiceJet and Kingfisher justified? Why or why not?'}, {'text': 'What is the evidence for and against the existence of the historical Jesus?'}, {'text': 'What specific educational reforms should President Donald Trump advocate to achieve better long-term economic growth for the United States?'}, {'text': 'If during a police car chase, a civilian car happens to get hit/damaged by a cop car in the midst of a pursuit, who bears the cost for the damage ...
# --------------------------------------------------
#  22%|██▎       | 9/40 [00:07<00:27,  1.14it/s]
# 250  -  -  -  -  -  -  -  -  -  -  [{'text': 'What causes soil erosion?'}, {'text': 'What does spirituality mean?'}, {'text': 'How can I send bulk SMS from a computer?'}, {'text': 'What is the missing item from the pattern?'}, {'text': 'Do I have a chance of getting a PhD in Cognitive Neuroscience as an applied linguistic master student who is currently working on language processing?'}, {'text': 'What is it like to be an Indian living in South Korea?'}, {'text': 'What is the full form of PhD?'}, {'text': 'What does a woman really mean when she says someone is desperate?'}, {'text': 'How do I shuffle two arrays into one array?'}, {'text': 'What can I do to get my vagina wet?'}, {'text': 'How do I delete thousands of old unread emails from my Gmail?'}, {'text': 'Why are firearms still so loud? Is it illegal to manufacture guns with built-in silencers?'}, {'text': 'Why the rain drops obtain spherical shape?'}, {'text': 'At what time should I drink green tea to be fit?'}, {'text': 'How can I become a conductor?'}, {'text': "What happens if I don't pay back any aspect of my loan in the UK?"}, {'text': 'How is the Lewis structure for carbonic acid determined?'}, {'text': 'Which are the best CA firms for articleship in Surat?'}, {'text': 'At what temperature do probiotic bacteria in yogurt die?'}, {'text': 'If we do not have data to learn from for a Bayesian Network, how do we create Conditional Probability Distribution tables?'}, {'text': 'What are some of the best WhatsApp jokes?'}, {'text': 'Why do men like to cheat?'}, {'text': 'Are veterans being told they cannot own firearms?'}, {'text': 'What are some lesser known facts about diamonds?'}, {'text': 'Can a pit beat a wolf?'}, {'text': 'What is your experience with ragging?'}, {'text': 'Is U.S. foreign policy in the Middle East hypocritical?'}, {'text': 'What is the difference between Kurti and Kurta?'}, {'text': 'What one should know for pursuing M.Tech?'}, {'text': 'What should everyone know about apples?'}, {'text': 'What kind of effect will a blue 15mg ABG morphine pill have on me?'}, {'text': 'What types of technical questions are asked in developer interviews?'}, {'text': 'What is cross-site scripting?'}, {'text': 'Why are maximum breaks rare in competition in snooker?'}, {'text': 'What are the levers in a negotiation to sell hot topical stories to magazines and newspapers?'}, {'text': 'Which are the best German universities for an MS in mechanical engineering?'}, {'text': 'Is it possible for an individual to become a trillionaire?'}, {'text': 'What are other animals who use fire like humans do?'}, {'text': "How can the word 'purloin' be used in a sentence?"}, {'text': 'Who was the first billionaire in first forbes 400 list?'}, {'text': 'What is your review of the SSC CGL tier 2 2016 exam?'}, {'text': 'Which lens is better AF-S or AF-P in nikon, overall practical use?'}, {'text': 'How should I make a decision?'}, {'text': 'What is the highest used application of multifunctional display?'}, {'text': 'Has a student ever made you (teacher) cry? Why?'}, {'text': 'What role can Hillary Clinton play now that her presidential hopes are extinguished?'}, {'text': 'Who was John the Baptist?'}, {'text': 'Is there still land that is unclaimed by anyone in the world?'}, {'text': "My father's school leaving certificate has a wrong date of birth and he doesn't have a birth certificate too, how would he get a passport?"}, {'text': 'What is the difference between creativity and talent?'}, {'text': 'How do I get Wifi without a password?'}, {'text': 'What are the best UK university for economics given I would like to go into banking?'}, {'text': "Is Kurt Vonnegut's style in his other books similar to his style in Slaughterhouse-Five?"}, {'text': 'What do you mean by learning?'}, {'text': 'What do you think about positive psychology?'}, {'text': 'What are all the different types of government?'}, {'text': 'Why are some bosses highly paranoid?'}, {'text': 'Is it necessary to learn java?'}, {'t ...
# --------------------------------------------------
#  25%|██▌       | 10/40 [00:08<00:26,  1.14it/s]
# 250  -  -  -  -  -  -  -  -  -  -  [{'text': 'What is the craziest story about North Korea?'}, {'text': 'What impact would GST have on agriculture sector?'}, {'text': 'By what framework may I take the application lock on iphone?'}, {'text': 'What is the way to clear eclipse console using Java?'}, {'text': 'What is the difference between attachment and love?'}, {'text': 'What is the difference between computer science, computer engineering, and software engineering?'}, {'text': 'If the Earth lost its oxygen for 5 seconds what would happen upon its return?'}, {'text': "I'm in love with my best friend, should I tell him I love him?"}, {'text': 'What are the different ways to earn money?'}, {'text': 'Which is best time to go for walk?'}, {'text': 'Is a good personal trainer worth it?'}, {'text': 'What is Bulletproof Coffee good for?'}, {'text': 'How do you push yourself beyond your limitations?'}, {'text': 'What will happen to India if Donald Trump wins?'}, {'text': 'How do I ask a girl out for coffee?'}, {'text': 'What is your opinion about keeping animals in zoos?'}, {'text': 'How do I post a question that was marked as needing improvement?'}, {'text': 'Is the phrase "Jack of all trades, master of none" true?'}, {'text': 'How do I increase my strength and stamina at 15?'}, {'text': 'Which is the best site to learn coding online for beginners?'}, {'text': "How can I tell my Catholic parents I'm an atheist?"}, {'text': 'Have you ever experienced lucid dreaming?'}, {'text': 'How much do uber drivers on Philadelphia?'}, {'text': 'Do you miss being a student?'}, {'text': "What happened to Saddam Hussein's body doubles after the war? Did any survive?"}, {'text': 'How should I stop being insecure?'}, {'text': 'How do I chat with a girl on Facebook?'}, {'text': 'How girls can increase their height after 18 years?'}, {'text': 'How many members in total are there in The Avengers Age of Ultron?'}, {'text': 'What do people think of Booktract.com?'}, {'text': 'What should i do to overcome depression ?'}, {'text': "Do animal's commit suicide?"}, {'text': 'Did Hitler have children and where are they?'}, {'text': 'Is learning computer science hard?'}, {'text': 'What is the best smartphone for under 25000 rs or $400 US?'}, {'text': 'Which unique commodities did Europeans trade on the Silk Road?'}, {'text': 'What is the best way to impress my girlfriend?'}, {'text': "Why can't an average human lift things weighing half his body weight?"}, {'text': 'Percentage of scientists who believe in evolution?'}, {'text': 'How do I find out what social site my boyfriend is using?'}, {'text': 'What knowledge should I prepare if I would like to have a solid background to do research about Graph Mining?'}, {'text': 'Farting releases stress do you agree?'}, {'text': 'What do the English think of Americans?'}, {'text': 'What does technology enthusiast mean?'}, {'text': "What's your New Year 2017 resolution?"}, {'text': 'What are some cool careers?'}, {'text': 'What is the exact status of Brahmins in India today?'}, {'text': 'Why are koi fish in Japan so expensive compared to koi fish sold in the US?'}, {'text': 'Are you an illegal immigrant if you cross the us border?'}, {'text': 'How would a population of cockroaches do on the surface of Mars?'}, {'text': 'What are some ways to find the atomic radius of an element?'}, {'text': 'How doctor vinay kumaran spares time to answer on Quora?'}, {'text': 'When was the last time that a U.S. general killed an enemy during combat?'}, {'text': 'Do guys fall for ugly girls?'}, {'text': 'What is the full life cycle of an enterprise server?'}, {'text': 'What is the best tourist destination in UK?'}, {'text': 'What are some maker spaces that are building a social movement beyond the Maker Movement?'}, {'text': 'Why do all of my questions get ignored on Quora?'}, {'text': 'Do rich people ever fly coach?'}, {'text': 'Why were rabies treatment shots formerly given in a set of 20 or more and in the stomach?'}, {'text': 'How can I us ...
# --------------------------------------------------
#  28%|██▊       | 11/40 [00:11<00:42,  1.46s/it]
# 250  -  -  -  -  -  -  -  -  -  -  [{'text': 'I am almost 500 pounds. Most of the weight is body fat. How do I go about using a skin caliper to measure body fat percentage?'}, {'text': 'Is U-Verse a cable or satellite provider?'}, {'text': 'Why do some people identify as different from their birth gender and do psychiatrists accept this as normal?'}, {'text': 'What is the small bottle of oil I got with my trimmer used for?'}, {'text': 'How do I revise for my theory test?'}, {'text': 'What was the most important event in history from the past 70 years?'}, {'text': 'What is the best method to obtain business credit? How do I avoid using my own credit?'}, {'text': 'Why are art and science equally important?'}, {'text': 'Can a J2EE developer get a job abroad?'}, {'text': 'When do the paralympic games start?'}, {'text': 'Why do people fear change?'}, {'text': 'What is the difference between the White House and the US Capitol Building?'}, {'text': 'What are examples of academic fraud?'}, {'text': 'Is there still a demand for market research focus group moderators? Or has it decreased?'}, {'text': 'How do you log in to Facebook if you forgot your password?'}, {'text': 'Does Microsoft regret investing in Apple in 1997?'}, {'text': 'How do I hack shadow fight 2 on android?'}, {'text': 'How can I lose body fat in my belly and chest?'}, {'text': 'How do I not worry about what others think or compare myself with them?'}, {'text': 'I want to learn the South Indian language. Which is a free site that will help me learn it?'}, {'text': "What should I do if I have a major crush on a close friend and I don't want to ruin our friendship?"}, {'text': 'Have netbooks disappeared?'}, {'text': 'Is it no coincidence that most of the worlds developed countries are in the Northern hemisphere?'}, {'text': "Why did you like Hitchhiker's Guide to the Galaxy?"}, {'text': "Who is Star Lord's father?"}, {'text': 'What is the difference between progressive and carryover effects in research?'}, {'text': 'Can a 18-200mm lens behave like a 35mm or 50mm lens?'}, {'text': 'What are some major landforms in Texas, and how do they compare to the most famous landforms in Utah?'}, {'text': 'How should one start learning Algorithms?'}, {'text': 'What is the Sharpe ratio?'}, {'text': 'What are the ways to get recruited to Google MTV?'}, {'text': 'What are scripting languages and programming languages?'}, {'text': 'Should I convince my boyfriend to quit medicine ?'}, {'text': 'How do you make a website like accountablehq.com in wordpress?'}, {'text': 'Does school damage ones creativity?'}, {'text': 'What are the most memorable acronyms for learning the treble and bass clef notes on the staff?'}, {'text': 'Do white women find black men attractive?'}, {'text': 'How do I have a book memory like Mike Ross in Suits?'}, {'text': 'What is software process model?'}, {'text': 'What are some cool facts about the Boeing 787 Dreamliner?'}, {'text': 'What is bad about eating expired eggs?'}, {'text': 'To which companies does TCS provide its services in Product Lifecycle Management(PLM)?'}, {'text': 'I sleep 4 hours in the night and then workout for 1:30 hours in the morning and sleep again. Is this right for my health?'}, {'text': 'Who is the best Indian journalist?'}, {'text': 'When did you first start masturbating?'}, {'text': 'Can someone provide me detail syllabus of digital logic for GATE CSE?'}, {'text': 'What are the average costs of starting up an IPTV company in the US?'}, {'text': 'Why do people love Manchester United so much?'}, {'text': 'What are benefits of NoFap?'}, {'text': 'What is the best way to keep your natural hair curly?'}, {'text': 'Which laptop is better? HP ay 079tx or HP ay008tx or something else under 40000inr?'}, {'text': 'What will be the consequences of stopping Rs 500 and 1000 currency notes on the economy overall?'}, {'text': 'What are some good romantic comedy movies?'}, {'text': "How did Assassin's Creed get greenlit? What's the backstory of how the m ...
# --------------------------------------------------
#  30%|███       | 12/40 [00:12<00:39,  1.41s/it]
# ...
# --------------------------------------------------
#  95%|█████████▌| 38/40 [00:46<00:02,  1.28s/it]
# 250  -  -  -  -  -  -  -  -  -  -  [{'text': 'How do I create a middle finger symbol with text?'}, {'text': 'What are the types of Rationality offered by Max Weber?'}, {'text': 'How do you reverse a linked list?'}, {'text': 'How was education during the Japanese occupation like in Singapore?'}, {'text': "In India, what are the things that women can do easily, but men can't?"}, {'text': 'How does spilled water damage a laptop?'}, {'text': 'What is your most embarrassing injury?'}, {'text': 'If I forgot my Facebook password, how do I reset it?'}, {'text': 'How can sell my land online?'}, {'text': "What's the difference between performance and efficiency?"}, {'text': 'What is an example of the word "dour" in a sentence?'}, {'text': 'Can I know the basics of hacking?'}, {'text': 'What statistical procedure would be used to determine black money after demonitisation?'}, {'text': 'What are some of the best places to visit in your country?'}, {'text': 'I have a client in the US who is ready to outsource me development work. Who in Pune can help me with taxes and payments receivable regulations for my IT company (which is not yet formed)?'}, {'text': "Why can't I have guy friends without people assuming they like me or I like them?"}, {'text': 'How do I switch my IT job?'}, {'text': 'Do you believe in luck? Why or why not?'}, {'text': "How could Muslim rulers allow their slaves to rule (slave Dynasty)? Is the concept of slavery in Islam different from today's version?"}, {'text': 'How can I become rich?'}, {'text': 'Will there ever be a moment where the whole planet will have been built?'}, {'text': 'How do I keep raccoons away?'}, {'text': 'For higher studies, are there any specific requirements for the US Co-signer?'}, {'text': 'Is Century Gothic a good font for a website?'}, {'text': 'What is the best way to learn Adobe Photoshop?'}, {'text': 'Who loved Lyanna more, Rhaegar or Robert?'}, {'text': 'Where can I catch a Dratini in Pokemon Sun / Moon?'}, {'text': 'What does a breast look like?'}, {'text': 'What are some good pick up lines which actually work?'}, {'text': 'How can I be a great lover?'}, {'text': 'What part of our brain generates dreams?'}, {'text': 'Would you invest in stocks or commodities? Why?'}, {'text': 'Was there any joint military operation of Russian and US troops, involving boots on the ground and live fire?'}, {'text': 'How do I can get more contributors on GitHub?'}, {'text': 'US Muslim brotherhood participant organizations?'}, {'text': 'Why did everyone forget about Joseph Kony so fast?'}, {'text': 'How many dollars did the store owner lose in the following scenario?'}, {'text': 'What is slyme?'}, {'text': 'How do I take the best picture of the night sky, stars and planets with a Canon 60d?'}, {'text': 'Is it possible to build a very basic app based on the Adwords API without programming skills?'}, {'text': 'Should Kobe Bryant retire?'}, {'text': 'When is racial profiling effective?'}, {'text': 'Which is the best IAS coaching institute in India?'}, {'text': 'What did you do to help you get through depression without taking medication or seeing a psychiatrist/counsellor/doctor?'}, {'text': 'Why is no one writing Harambe and Shrek fan-fiction yet?'}, {'text': 'How can I secretly take screenshots on Snapchat?'}, {'text': 'Is it possible for sites and publications that publish web content to do anything to be optimized in Spark interest categories?'}, {'text': 'To what extent is racism illegal in the United States?'}, {'text': 'What is the best way of presentation of any software?'}, {'text': 'What are examples of devices that convert electrical energy to mechanical energy? How do they work?'}, {'text': 'Did the US know about concentration camps before the end of World War II?'}, {'text': 'What is the speed of earth?'}, {'text': 'What are some uses of domestic animals?'}, {'text': 'Which is the best place to reside in India and Why?'}, {'text': 'Which is a suitable inpatient drug and alcohol rehab center near Ja ...
# --------------------------------------------------
#  98%|█████████▊| 39/40 [00:47<00:01,  1.23s/it]
# 250  -  -  -  -  -  -  -  -  -  -  [{'text': 'What are the distinct behavioral differences between an introvert and a schizoid?'}, {'text': 'What is global solidarity?'}, {'text': 'What can you change in your life to become an everyday hero?'}, {'text': 'How do I recover a lost password or account for gmail?'}, {'text': 'Which other countries did demonetization?'}, {'text': 'How can you study economics on Quora?'}, {'text': 'Is sex painful during pregnancy?'}, {'text': 'Why do some people believe that the world is flat?'}, {'text': 'How can I get back my original skin colour? Its tanned.'}, {'text': 'Is it ok if a IT professional works on a freelancing work?'}, {'text': 'How do I prepare for the NMAT in 10 days?'}, {'text': "How long would it take to load a 1GB file into RAM if the speed of the drive the file was stored on didn't matter?"}, {'text': 'Can $B creative breakthroughs like Uber happen on demand?'}, {'text': 'What are the problems after upgrading to Windows 10?'}, {'text': 'What is it like to be a homoromantic heterosexual man?'}, {'text': 'What is the best advice ever your father gave you?'}, {'text': 'Are peanuts healthy, especially to eat every day?'}, {'text': 'How do I split the mortgage interest rate tax deduction between two people?'}, {'text': 'Do Russians consider themselves as western or eastern?'}, {'text': 'What is the difference between Muslim and Christian?'}, {'text': "What's your favorite Android mobile App and why?"}, {'text': 'What should I do with daydream?'}, {'text': 'Why has cutoff of JEE Mains dropped to 100 this year (2016)?'}, {'text': 'Do men cry when they miss their girlfriends?'}, {'text': 'How do you improve focus?'}, {'text': 'How do we shed emotional baggage?'}, {'text': 'Can Americans hold dual citizenship?'}, {'text': 'How do I respond/acknowledge my boss for the task assignment in email? Is it fine to say "Thank you so much for sending the task. I will get back to you once I get questions?"'}, {'text': "What's your nickname?"}, {'text': 'What is the best basketball workout for dunk?'}, {'text': 'Has the human race jumped the shark?'}, {'text': 'How do I get a birth certificate in India if it was not registered when I was born?'}, {'text': 'Why do some women enjoy dressing revealingly?'}, {'text': "If Mars was Earth's moon, would the Apollo program have ended in the early 70's?"}, {'text': 'Will I lose weight if I drink every day 2 cups of green tea for about 2 weeks?'}, {'text': 'Does "Hikari Oe" the musical composer have Classic Autism?'}, {'text': 'What is the latency between camera trigger and the actual video taking of a GoPro Hero 4 Black?'}, {'text': 'What is the significance of second order derivative?'}, {'text': 'My GRE score is 310. My TOEFL score is 93. My B.Tech percentage is 79. What are some universities where tuition fees are low and there is a chance of getting TA and part time jobs?'}, {'text': 'How do I unlock carrier locked iphones?'}, {'text': 'What is the best coaching institute for the CAT preparation in Delhi?'}, {'text': 'What is bestmytest.com?'}, {'text': 'What is equity in investment domain?'}, {'text': 'What are some weird questions you have been asked?'}, {'text': "What's the point of learning how to program websites if you can just use a content management system?"}, {'text': 'What is the busiest street in manhattan?'}, {'text': 'What will be the top in-demand programming languages / skills / frameworks in 2017?'}, {'text': 'What are the differences between external and internal conflict?'}, {'text': 'How many of you can still be a gentleman even after seeing a woman in provocative clothes or nude?'}, {'text': 'What are the examples of a presence of mind?'}, {'text': "What are some mind-blowing smartphone gadgets that exist that most people don't know about?"}, {'text': 'What are some of the characteristics of Baroque art?'}, {'text': 'What is a black hole? How can we understand it?'}, {'text': 'What are the chances that Barack Obama will again become t ...
# --------------------------------------------------
# 100%|██████████| 40/40 [00:48<00:00,  1.21s/it]
# 250  -  -  -  -  -  -  -  -  -  -  [{'text': 'What are some major technical breakthroughs in recent video games?'}, {'text': 'How can I get 100 likes on my Facebook photo?'}, {'text': 'What is the difference between Sin and Crime?'}, {'text': 'What are the sites to download TV series?'}, {'text': 'Will the 2016 US presidential election be close?'}, {'text': 'What is the best SEO company in Delhi, India?'}, {'text': "Moto g4 screen is all black lights light up but can't see anything reset tricks do not work?"}, {'text': 'How can I publish theses on agriculture on the International Library for Thesis?'}, {'text': 'What is best i5 6th or 7th gen?'}, {'text': 'What is the way to overcome the stage fear?'}, {'text': 'What is your horror story at NIT?'}, {'text': "What's the best way to extend battery life on my Android phone?"}, {'text': 'Hypothetical scenario: the US military is forced to choose between giving up all its Apache Gunships or all its Black Hawks. Which do they choose?'}, {'text': 'Is it good to switch to edgeverve from Tcs after two years of experience?'}, {'text': 'Why is there a Canadian basketball team, the Toronto Raptors, in the NBA? Why is there only one?'}, {'text': 'How do you sync music in your iTunes to your iPhone?'}, {'text': 'What would happen to the universe if suddenly time stopped?'}, {'text': 'Why do so many religious people believe in healing miracles?'}, {'text': 'What are covalent and ionic bonds? What are some examples?'}, {'text': 'Who is more likely to reveal or confirm the R+L=J? Bran Stark or Howland Reed?'}, {'text': 'What is the work of a data scientist?'}, {'text': 'How many sentient beings did Luke Skywalker kill when he destroyed the Death Star?'}, {'text': 'How can I copy bookmarks from Chrome?'}, {'text': "Can one learn the foundations of advanced math by reading and mastering Euler's Elements of Algebra, Euclid's Elements, and Newton's Principia?"}, {'text': 'How often should you be drinking green tea in a day?'}, {'text': 'What is the best Python Twitter library to use with the Twitter API?'}, {'text': 'Why did President Obama abstain on the UN vote against Israeli settlements?'}, {'text': 'What do you think of the decision by the Indian government to demonetize 500 and 1000 rupee notes?'}, {'text': 'How should I do when I have a crush on my friend?'}, {'text': 'Which happened before Ramayana or Mahabharata?'}, {'text': 'How do I start up a business with 5 lakhs?'}, {'text': 'How long to use 3m 9000in face mask?'}, {'text': 'Is it legal to pursue two degrees simultaneously (one regular and the other in distance education) from different universities? And if I have done so, will both the certificates be valid together?'}, {'text': "Why doesn't Trump release at least some of his past tax returns that are no longer under audit?"}, {'text': 'What are some great inspirational songs?'}, {'text': 'Can listening to music, playing the computer or watching television after studying make you forget what you just learnt?'}, {'text': 'How do I repair a broken Apple iPad screen?'}, {'text': 'Why do I still feel lonely even though I have good friends, good family, good education and a good environment?'}, {'text': 'Can you suggest configuration for assembling a PC to all graphic and design works for my magazine and other publications?'}, {'text': "What's the answer to question 42 of The Impossible Quiz?"}, {'text': 'Is ejaculation within a couple of strokes during masturbation a sign of premature ejaculation given you can maintain your erection as long as you can?'}, {'text': 'Why do people take advantage of good and kind people?'}, {'text': 'My Bit Torrent download is stuck at connecting peers. It was working fine until last night, and when I opened the PC this morning I was not able to download anything. There is a healthy number of seeds in the file too, more than 800. How do I proceed downloading with Bit Torrent?'}, {'text': 'What is the Seventh Trumpet and The Rapture?'}, {'text': 'Do animals ...
# --------------------------------------------------

# %% [markdown]
# insert/upsert to pincode with embeddings and metadata

# %%
for i in tqdm(range(0, len(questions), batch)):
    i_end = min(i+batch, len(questions))
    ids = [str(x) for x in range(i, i_end)]
    metadatas = [{'text': text} for text in questions[i:i_end]]
    xc = model.encode(questions[i:i_end])
    records = zip(ids, xc, metadatas)
    index.upsert(vectors=records)
# Out:
# 100%|██████████| 40/40 [01:06<00:00,  1.66s/it]

# %%
index.describe_index_stats()
# Out:
# {'dimension': 384,
#  'index_fullness': 0.0,
#  'namespaces': {'': {'vector_count': 10000}},
#  'total_vector_count': 10000}

# %% [markdown]
# Below code:
#
# index.query(...): This function call performs the actual search. The index is a vector search index, potentially managed by a library such as Pinecone, Faiss, or Annoy.
#
# top_k=10: The search query returns the top 10 results that are most similar to the provided vector.
# vector=embedding: This specifies the query vector.
#
# include_metadata=True: Indicates that the query should return metadata associated with each result. Metadata often includes original text or additional information useful for identifying or understanding the results.
#
# include_values=False: Specifies that the actual vector values of the results should not be included in the response. This is useful for reducing response size if only metadata is required.
#
#     > What Does include_values=False Do?
#         When you perform a vector search query, the search engine can return various pieces of information about each of the matches found. These pieces of information can include:
#
#             Metadata: This is data associated with each item in the vector database, such as descriptions, titles, or any other contextual information that was stored with the vector. Metadata helps in identifying or understanding what each vector represents in human-readable form.
#
#             Vector Values: These are the actual high-dimensional data points (numerical values) of each vector. Vectors are the core component of how items are stored and searched within the system. They represent the item in a mathematical space.

# %%
# small helper function so we can repeat queries later
def query(query):
  embedding = model.encode(query).tolist()
  results = index.query(top_k=10, vector=embedding, include_metadata=True, include_values=False)
  for result in results['matches']:
    print(f"{round(result['score'], 2)}: {result['metadata']['text']}")

# %%
query('AM I BATMAN!!!!')
# Out:
# 0.51: Who is a better superhero: Batman or Spider-Man?
# 0.5: Why does Joker in Batman so famous?
# 0.45: Who would win a fight between wolverine and Batman?
# 0.45: What fighting style does Batman use in Batman vs Superman?
# 0.44: How should I prepare myself to be a real-life Joker as in The Dark Knight?
# 0.43: Is the Joker in the Suicide Squad comics?
# 0.4: If Batman had gone to Hogwarts, which house would he be in?
# 0.37: What is the full form of DC in DC comics?
# 0.37: The Dark Knight Rises (2012 movie): Why didn't Batman kill Bane in this scene when he had a clear shot at him with "the bat"?
# 0.36: Why does The Joker burn the money in The Dark Knight?
